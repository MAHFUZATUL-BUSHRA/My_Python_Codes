# %%
import pandas as pd
import yfinance

# %%
stock_data = yfinance.download(tickers= "AAPL GOOG", group_by = 'ticker', start = "2005-01-01", end = "2025-04-20", auto_adjust= True)
stock_data
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker            GOOG                                                 \
# Price             Open        High         Low       Close     Volume
# Date
# 2005-01-03    4.893393    5.048079    4.845303    5.025025  636143518
# 2005-01-04    4.992551    5.030479    4.796220    4.821506  552298420
# 2005-01-05    4.795476    4.880999    4.765234    4.796964  330698912
# 2005-01-06    4.835883    4.856211    4.653434    4.674010  417041336
# 2005-01-07    4.725819    4.815309    4.679711    4.805393  387964757
# ...                ...         ...         ...         ...        ...
# 2025-04-11  155.585007  159.860001  155.585007  159.399994   22582000
# 2025-04-14  162.309998  164.029999  159.919998  161.470001   18255900
# 2025-04-15  161.570007  162.050003  157.645004  158.679993   15690800
# 2025-04-16  155.470001  158.179993  153.910004  155.500000   16921500
# ...

# %%
stock_data[:10]
# Out:
# Ticker          GOOG                                               AAPL  \
# Price           Open      High       Low     Close     Volume      Open
# Date
# 2005-01-03  4.893393  5.048079  4.845303  5.025025  636143518  0.974732
# 2005-01-04  4.992551  5.030479  4.796220  4.821506  552298420  0.959835
# 2005-01-05  4.795476  4.880999  4.765234  4.796964  330698912  0.969916
# 2005-01-06  4.835883  4.856211  4.653434  4.674010  417041336  0.973076
# 2005-01-07  4.725819  4.815309  4.679711  4.805393  387964757  0.978042
# 2005-01-10  4.821505  4.910747  4.755318  4.835388  302714411  1.050717
# 2005-01-11  4.849269  4.901079  4.788782  4.797708  279391317  1.026944
# 2005-01-12  4.817291  4.856954  4.722349  4.843320  328338096  0.984813
# 2005-01-13  4.843320  4.893146  4.810350  4.842081  275002929  1.109100
# 2005-01-14  4.858689  4.958094  4.812334  4.957103  387057368  1.057037
#
# Ticker
# Price           High       Low     Close      Volume
# Date
# ...

# %%
# prompt: Download the Apple Stock Data (AAPL)

import yfinance as yf

# Download the Apple stock data
aapl_data = yf.download("AAPL", start="2000-01-01", end="2025-04-01", auto_adjust=True)

# Display the first few rows of the data
print(aapl_data.head())

# %% [markdown]
# **Importing the Stock Market Index of USA, Germany, Englang & Japan**

# %%
df = pd.read_csv("Index2018.csv")
df.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6269 entries, 0 to 6268
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6269 non-null   object
#  1   spx     6269 non-null   float64
#  2   dax     6269 non-null   float64
#  3   ftse    6269 non-null   float64
#  4   nikkei  6269 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 245.0+ KB

# %%
df.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.spx.plot(figsize = (20,6), title = "S&P500 Prices")
plt.show()

# %%
df.date = pd.to_datetime(df.date, dayfirst = True)
df.head()
# Out:
#         date     spx      dax     ftse    nikkei
# 0 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1 1994-01-10  475.27  2225.00  3440.58  18443.44
# 2 1994-01-11  474.13  2228.10  3413.77  18485.25
# 3 1994-01-12  474.17  2182.06  3372.02  18793.88
# 4 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
df.set_index("date").head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
df.head()
# Out:
#         date     spx      dax     ftse    nikkei
# 0 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1 1994-01-10  475.27  2225.00  3440.58  18443.44
# 2 1994-01-11  474.13  2228.10  3413.77  18485.25
# 3 1994-01-12  474.17  2182.06  3372.02  18793.88
# 4 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
df.set_index("date", inplace = True)
df.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
df.spx.plot(figsize = (20,6), title = "S&P500 Prices")
plt.show()

# %%
df = df.asfreq('b')

# %%
import numpy as np

# %%
wn = np.random.normal(loc = df.spx.mean(), scale = df.spx.std(), size = len(df))
wn
# Out:
# array([1954.42330331, 1258.76873306,  253.79853445, ..., 1505.44188414,
#        1254.17972932, 1356.52163547])

# %%
df['wn'] = wn

# %%
df['wn'] = pd.Series(df['wn'], index=df.index)

# %%
df.head()
# Out:
#                spx      dax     ftse    nikkei           wn
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01  1178.364557
# 1994-01-10  475.27  2225.00  3440.58  18443.44   734.856427
# 1994-01-11  474.13  2228.10  3413.77  18485.25  1934.358487
# 1994-01-12  474.17  2182.06  3372.02  18793.88  1929.944569
# 1994-01-13  472.47  2142.37  3360.01  18577.26  1399.013969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6277 entries, 1994-01-07 to 2018-01-29
# Freq: B
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   spx     6269 non-null   float64
#  1   dax     6269 non-null   float64
#  2   ftse    6269 non-null   float64
#  3   nikkei  6269 non-null   float64
#  4   wn      6277 non-null   float64
# dtypes: float64(5)
# memory usage: 294.2 KB

# %%
df.describe()
# Out:
#                spx           dax         ftse        nikkei           wn
# count  6269.000000   6269.000000  6269.000000   6269.000000  6277.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700  1283.577896
# std     487.586473   2754.361032  1145.572428   4043.122953   494.970247
# min     438.920000   1911.700000  2876.600000   7054.980000  -576.110906
# 25%     990.671905   4069.350000  4486.100000  10709.290000   947.650938
# 50%    1233.420000   5773.340000  5662.430000  15028.170000  1282.003198
# 75%    1459.987747   7443.070000  6304.250000  17860.470000  1620.327696
# max    2872.867839  13559.600000  7778.637689  24124.150000  3010.085514

# %%
df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-cf0a01c8b88f> in <cell line: 0>()
# ----> 1 df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
#       2 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
del df['wn']

# %%
df.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
wn = np.random.normal(loc = df.spx.mean(), scale = df.spx.std(), size = len(df))
df['wn'] = wn
df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-3dc0d6d11795> in <cell line: 0>()
#       1 wn = np.random.normal(loc = df.spx.mean(), scale = df.spx.std(), size = len(df))
#       2 df['wn'] = wn
# ----> 3 df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
#       4 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
wn = np.random.normal(loc = df.spx.mean(), scale = df.spx.std(), size = len(df))
df['wn'] = pd.Series(wn, index=df.index) # Convert wn to a Pandas Series with the same index as df
df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-4f7e6c90833d> in <cell line: 0>()
#       1 wn = np.random.normal(loc = df.spx.mean(), scale = df.spx.std(), size = len(df))
#       2 df['wn'] = pd.Series(wn, index=df.index) # Convert wn to a Pandas Series with the same index as df
# ----> 3 df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
#       4 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
# prompt: Insert the following numpy.ndarray into my dataframe (df) as a column; Not as a ndarray.
# wn = np.random.normal(loc = df.spx.mean(), scale = df.spx.std(), size = len(df))

# Assuming 'df' and 'wn' are already defined as in your previous code

df['wn'] = pd.Series(wn, index=df.index)

# %%
df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-cf0a01c8b88f> in <cell line: 0>()
# ----> 1 df.wn.plot(figsize = (20,6), title = "White Noise Pattern")
#       2 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
# prompt: create a plot of wn against the index date

import matplotlib.pyplot as plt

# Assuming 'df' and 'wn' are already defined as in your previous code
# and 'df' has a 'date' index.

plt.figure(figsize=(20, 6))
plt.plot(df.index, df['wn'])  # Plot wn against the date index
plt.xlabel("Date")
plt.ylabel("wn")
plt.title("wn against Date")
plt.grid(True)
plt.show()

# %% [markdown]
# Augmented Dickey Fuller Test (ADF)
#
# AIC, BIC [less is better]
#
# Log Likelihood Test
